# %%
# %load_ext autoreload
# %autoreload 2

import tqdm, sys, os, time, logging, warnings
from numba.core.errors import NumbaDeprecationWarning, NumbaPendingDeprecationWarning
warnings.simplefilter('ignore', category=NumbaDeprecationWarning)
warnings.simplefilter('ignore', category=NumbaPendingDeprecationWarning)

import pandas as pd
import numpy as np
import scipy as sp
import scipy.sparse as sps

import scanpy as sc
import anndata as ad
import muon as mu
import scvi

import plotly.express as px
import plotly.graph_objects as go
# sc.set_figure_params(dpi=100, fontsize=10, figsize="8,8", color_map='viridis', transparent=True)
from sklearn.metrics import adjusted_rand_score as ari
# Out:
# Global seed set to 0

# %% [markdown]
# # Load

# %%
mdata = mu.read_h5mu("data/processed/scRNAseq_snRNAseq_filteredQC_processedPCA.h5mu")
scrna = mdata['scrna']
snrna = mdata['snrna']

mdata.X = sps.vstack([mdata['scrna'].X, mdata['snrna'].X])
mdata
# Out:
# MuData object with n_obs × n_vars = 258555 × 31053
#   obs:	'class_label', 'cluster_color', 'cluster_id', 'cluster_label', 'gene.counts', 'size', 'subclass_label', 'umi.counts', 'dataset'
#   var:	'highly_variable'
#   uns:	'neighbors', 'umap'
#   obsm:	'X_pca', 'X_umap'
#   obsp:	'connectivities', 'distances'
#   2 modalities
#     scrna:	74132 x 31053
#       obs:	'Amp_Date', 'Amp_Name', 'Amp_PCR_cyles', 'Cell_Capture', 'Donor', 'Gender', 'Lib_Cells', 'Lib_Date', 'Lib_Name', 'Lib_PCR_cycles', 'Lib_PassFail', 'Lib_type', 'Live_Cells', 'Live_percent', 'Mean_Reads_perCell', 'Median_Genes_perCell', 'Median_UMI_perCell', 'Region', 'Replicate_Lib', 'Saturation', 'Seq_batch', 'Total_Cells', 'aggr_num', 'class_label', 'cluster_color', 'cluster_id', 'cluster_label', 'doublet.score', 'exp_component_name', 'gene.counts', 'library_id', 'mapped_reads', 'method', 'nonconf_mapped_reads', 'size', 'subclass_label', 'total.reads', 'tube_barcode', 'umi.counts', 'unmapped_reads', 'dataset'
#       var:	'gene_id', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#       uns:	'hvg', 'log1p', 'neighbors', 'pca', 'umap'
#       obsm:	'X_pca', 'X_umap', 'counts'
#       varm:	'PCs'
#       obsp:	'connectivities', 'distances'
#     snrna:	184423 x 31053
#       obs:	'Allen.class_label', 'Allen.cluster_color', 'Allen.cluster_id', 'Allen.cluster_label', 'Allen.subclass_label', 'Broad.QC.Mito', 'Broad.QC.doublet', 'Broad.passQC', 'Comb.QC', 'MALE', 'QC', 'cl', 'class_label', 'cluster', 'cluster_color', 'cluster_id', 'cluster_label', 'comb.QC', 'dataset', 'gene.counts', 'nGene', 'nUMI', 'size', 'subclass_label', 'umi.counts'
#       var:	'gene_id', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#       uns:	'hvg', 'log1p', 'neighbors', 'pca', 'umap'
#       obsm:	'X_pca', 'X_umap', 'counts'
#       varm:	'PCs'
#       obsp:	'connectivities', 'distances'

# %%
mdata.X[:5, :5].todense()
# Out:
# matrix([[3.7340188 , 0.        , 0.        , 0.        , 0.        ],
#         [2.933109  , 0.        , 0.        , 0.        , 0.        ],
#         [3.1178575 , 0.414911  , 0.        , 0.        , 0.        ],
#         [3.3489263 , 0.        , 0.        , 0.38774753, 0.        ],
#         [3.7994354 , 1.0549483 , 0.        , 0.        , 0.        ]],
#        dtype=float32)

# %%
scrna.X[:5, :5].todense()
# Out:
# matrix([[3.7340188 , 0.        , 0.        , 0.        , 0.        ],
#         [2.933109  , 0.        , 0.        , 0.        , 0.        ],
#         [3.1178575 , 0.414911  , 0.        , 0.        , 0.        ],
#         [3.3489263 , 0.        , 0.        , 0.38774753, 0.        ],
#         [3.7994354 , 1.0549483 , 0.        , 0.        , 0.        ]],
#        dtype=float32)

# %%
scrna.obsm['counts'][:5, :5].todense()
# Out:
# matrix([[49.,  0.,  0.,  0.,  0.],
#         [14.,  0.,  0.,  0.,  0.],
#         [42.,  1.,  0.,  0.,  0.],
#         [58.,  0.,  0.,  1.,  0.],
#         [70.,  3.,  0.,  0.,  0.]], dtype=float32)

# %%
scrna
# Out:
# AnnData object with n_obs × n_vars = 74132 × 31053
#     obs: 'Amp_Date', 'Amp_Name', 'Amp_PCR_cyles', 'Cell_Capture', 'Donor', 'Gender', 'Lib_Cells', 'Lib_Date', 'Lib_Name', 'Lib_PCR_cycles', 'Lib_PassFail', 'Lib_type', 'Live_Cells', 'Live_percent', 'Mean_Reads_perCell', 'Median_Genes_perCell', 'Median_UMI_perCell', 'Region', 'Replicate_Lib', 'Saturation', 'Seq_batch', 'Total_Cells', 'aggr_num', 'class_label', 'cluster_color', 'cluster_id', 'cluster_label', 'doublet.score', 'exp_component_name', 'gene.counts', 'library_id', 'mapped_reads', 'method', 'nonconf_mapped_reads', 'size', 'subclass_label', 'total.reads', 'tube_barcode', 'umi.counts', 'unmapped_reads', 'dataset'
#     var: 'gene_id', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'hvg', 'log1p', 'neighbors', 'pca', 'umap'
#     obsm: 'X_pca', 'X_umap', 'counts'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'

# %% [markdown]
# # SCVI

# %%
mdata.obs
# Out:
#                                              scrna:Amp_Date
# sample_name
# AAACCCAAGCTTCATG-1L8TX_181211_01_G12             11/29/2018  \
# AAACCCAAGTGAGGTC-1L8TX_181211_01_G12             11/29/2018
# AAACCCACACCAGCCA-1L8TX_181211_01_G12             11/29/2018
# AAACCCAGTGAACGGT-1L8TX_181211_01_G12             11/29/2018
# AAACCCAGTGGCATCC-1L8TX_181211_01_G12             11/29/2018
# ...                                                     ...
# pBICCNsMMrMOpRMiM006d190320_TTTGGTTCATGAGTAA            NaN
# pBICCNsMMrMOpRMiM006d190320_TTTGGTTTCGCAAGAG            NaN
# pBICCNsMMrMOpRMiM006d190320_TTTGTTGAGACTCTTG            NaN
# pBICCNsMMrMOpRMiM006d190320_TTTGTTGTCACCTTGC            NaN
# pBICCNsMMrMOpRMiM006d190320_TTTGTTGTCATGCTAG            NaN
#
#                                                   scrna:Amp_Name
# sample_name
# AAACCCAAGCTTCATG-1L8TX_181211_01_G12          A8TX_181129_03_A03  \
# AAACCCAAGTGAGGTC-1L8TX_181211_01_G12          A8TX_181129_03_A03
# AAACCCACACCAGCCA-1L8TX_181211_01_G12          A8TX_181129_03_A03
# AAACCCAGTGAACGGT-1L8TX_181211_01_G12          A8TX_181129_03_A03
# AAACCCAGTGGCATCC-1L8TX_181211_01_G12          A8TX_181129_03_A03
# ...                                                          ...
# pBICCNsMMrMOpRMiM006d190320_TTTGGTTCATGAGTAA                 NaN
# pBICCNsMMrMOpRMiM006d190320_TTTGGTTTCGCAAGAG                 NaN
# pBICCNsMMrMOpRMiM006d190320_TTTGTTGAGACTCTTG                 NaN
# pBICCNsMMrMOpRMiM006d190320_TTTGTTGTCACCTTGC                 NaN
# pBICCNsMMrMOpRMiM006d190320_TTTGTTGTCATGCTAG                 NaN
#
#                                               scrna:Amp_PCR_cyles
# sample_name
# AAACCCAAGCTTCATG-1L8TX_181211_01_G12                         12.0  \
# AAACCCAAGTGAGGTC-1L8TX_181211_01_G12                         12.0
# AAACCCACACCAGCCA-1L8TX_181211_01_G12                         12.0
# AAACCCAGTGAACGGT-1L8TX_181211_01_G12                         12.0
# AAACCCAGTGGCATCC-1L8TX_181211_01_G12                         12.0
# ...                                                           ...
# pBICCNsMMrMOpRMiM006d190320_TTTGGTTCATGAGTAA                  NaN
# pBICCNsMMrMOpRMiM006d190320_TTTGGTTTCGCAAGAG                  NaN
# pBICCNsMMrMOpRMiM006d190320_TTTGTTGAGACTCTTG                  NaN
# pBICCNsMMrMOpRMiM006d190320_TTTGTTGTCACCTTGC                  NaN
# pBICCNsMMrMOpRMiM006d190320_TTTGTTGTCATGCTAG                  NaN
#
#                                               scrna:Cell_Capture scrna:Donor
# sample_name
# AAACCCAAGCTTCATG-1L8TX_181211_01_G12                      5898.0      426003  \
# AAACCCAAGTGAGGTC-1L8TX_181211_01_G12                      5898.0      426003
# AAACCCACACCAGCCA-1L8TX_181211_01_G12                      5898.0      426003
# AAACCCAGTGAACGGT-1L8TX_181211_01_G12                      5898.0      426003
# AAACCCAGTGGCATCC-1L8TX_181211_01_G12                      5898.0      426003
# ...                                                          ...         ...
# pBICCNsMMrMOpRMiM006d190320_TTTGGTTCATGAGTAA                 NaN         NaN
# pBICCNsMMrMOpRMiM006d190320_TTTGGTTTCGCAAGAG                 NaN         NaN
# pBICCNsMMrMOpRMiM006d190320_TTTGTTGAGACTCTTG                 NaN         NaN
# pBICCNsMMrMOpRMiM006d190320_TTTGTTGTCACCTTGC                 NaN         NaN
# pBICCNsMMrMOpRMiM006d190320_TTTGTTGTCATGCTAG                 NaN         NaN
#
#                                              scrna:Gender  scrna:Lib_Cells
# sample_name
# AAACCCAAGCTTCATG-1L8TX_181211_01_G12                 Male           9733.0  \
# AAACCCAAGTGAGGTC-1L8TX_181211_01_G12                 Male           9733.0
# AAACCCACACCAGCCA-1L8TX_181211_01_G12                 Male           9733.0
# AAACCCAGTGAACGGT-1L8TX_181211_01_G12                 Male           9733.0
# AAACCCAGTGGCATCC-1L8TX_181211_01_G12                 Male           9733.0
# ...                                                   ...              ...
# pBICCNsMMrMOpRMiM006d190320_TTTGGTTCATGAGTAA          NaN              NaN
# pBICCNsMMrMOpRMiM006d190320_TTTGGTTTCGCAAGAG          NaN              NaN
# pBICCNsMMrMOpRMiM006d190320_TTTGTTGAGACTCTTG          NaN              NaN
# pBICCNsMMrMOpRMiM006d190320_TTTGTTGTCACCTTGC          NaN              NaN
# pBICCNsMMrMOpRMiM006d190320_TTTGTTGTCATGCTAG          NaN              NaN
#
#                                              scrna:Lib_Date
# sample_name
# AAACCCAAGCTTCATG-1L8TX_181211_01_G12             12/11/2018  \
# AAACCCAAGTGAGGTC-1L8TX_181211_01_G12             12/11/2018
# AAACCCACACCAGCCA-1L8TX_181211_01_G12             12/11/2018
# AAACCCAGTGAACGGT-1L8TX_181211_01_G12             12/11/2018
# AAACCCAGTGGCATCC-1L8TX_181211_01_G12             12/11/2018
# ...                                                     ...
# pBICCNsMMrMOpRMiM006d190320_TTTGGTTCATGAGTAA            NaN
# pBICCNsMMrMOpRMiM006d190320_TTTGGTTTCGCAAGAG            NaN
# pBICCNsMMrMOpRMiM006d190320_TTTGTTGAGACTCTTG            NaN
# pBICCNsMMrMOpRMiM006d190320_TTTGTTGTCACCTTGC            NaN
# pBICCNsMMrMOpRMiM006d190320_TTTGTTGTCATGCTAG            NaN
#
#                                                   scrna:Lib_Name
# sample_name
# AAACCCAAGCTTCATG-1L8TX_181211_01_G12          L8TX_181211_01_G12  \
# AAACCCAAGTGAGGTC-1L8TX_181211_01_G12          L8TX_181211_01_G12
# AAACCCACACCAGCCA-1L8TX_181211_01_G12          L8TX_181211_01_G12
# AAACCCAGTGAACGGT-1L8TX_181211_01_G12          L8TX_181211_01_G12
# AAACCCAGTGGCATCC-1L8TX_181211_01_G12          L8TX_181211_01_G12
# ...                                                          ...
# pBICCNsMMrMOpRMiM006d190320_TTTGGTTCATGAGTAA                 NaN
# pBICCNsMMrMOpRMiM006d190320_TTTGGTTTCGCAAGAG                 NaN
# pBICCNsMMrMOpRMiM006d190320_TTTGTTGAGACTCTTG                 NaN
# pBICCNsMMrMOpRMiM006d190320_TTTGTTGTCACCTTGC                 NaN
# pBICCNsMMrMOpRMiM006d190320_TTTGTTGTCATGCTAG                 NaN
#
#                                               scrna:Lib_PCR_cycles  ...
# sample_name                                                         ...
# AAACCCAAGCTTCATG-1L8TX_181211_01_G12                           9.0  ...  \
# AAACCCAAGTGAGGTC-1L8TX_181211_01_G12                           9.0  ...
# AAACCCACACCAGCCA-1L8TX_181211_01_G12                           9.0  ...
# AAACCCAGTGAACGGT-1L8TX_181211_01_G12                           9.0  ...
# AAACCCAGTGGCATCC-1L8TX_181211_01_G12                           9.0  ...
# ...                                                            ...  ...
# pBICCNsMMrMOpRMiM006d190320_TTTGGTTCATGAGTAA                   NaN  ...
# pBICCNsMMrMOpRMiM006d190320_TTTGGTTTCGCAAGAG                   NaN  ...
# pBICCNsMMrMOpRMiM006d190320_TTTGTTGAGACTCTTG                   NaN  ...
# pBICCNsMMrMOpRMiM006d190320_TTTGTTGTCACCTTGC                   NaN  ...
# pBICCNsMMrMOpRMiM006d190320_TTTGTTGTCATGCTAG                   NaN  ...
#
#                                              snrna:nUMI    class_label
# sample_name
# AAACCCAAGCTTCATG-1L8TX_181211_01_G12                NaN  Glutamatergic  \
# AAACCCAAGTGAGGTC-1L8TX_181211_01_G12                NaN  Glutamatergic
# AAACCCACACCAGCCA-1L8TX_181211_01_G12                NaN  Glutamatergic
# AAACCCAGTGAACGGT-1L8TX_181211_01_G12                NaN  Glutamatergic
# AAACCCAGTGGCATCC-1L8TX_181211_01_G12                NaN      GABAergic
# ...                                                 ...            ...
# pBICCNsMMrMOpRMiM006d190320_TTTGGTTCATGAGTAA    20193.0  Glutamatergic
# pBICCNsMMrMOpRMiM006d190320_TTTGGTTTCGCAAGAG     2858.0   Non-Neuronal
# pBICCNsMMrMOpRMiM006d190320_TTTGTTGAGACTCTTG    35854.0  Glutamatergic
# pBICCNsMMrMOpRMiM006d190320_TTTGTTGTCACCTTGC    23493.0  Glutamatergic
# pBICCNsMMrMOpRMiM006d190320_TTTGTTGTCATGCTAG    22385.0  Glutamatergic
#
#                                               cluster_color cluster_id
# sample_name
# AAACCCAAGCTTCATG-1L8TX_181211_01_G12                #52CA74         42  \
# AAACCCAAGTGAGGTC-1L8TX_181211_01_G12                #5DDB65         41
# AAACCCACACCAGCCA-1L8TX_181211_01_G12                #52CA74         42
# AAACCCAGTGAACGGT-1L8TX_181211_01_G12                #5DDB65         41
# AAACCCAGTGGCATCC-1L8TX_181211_01_G12                #B09FFF         20
# ...                                                     ...        ...
# pBICCNsMMrMOpRMiM006d190320_TTTGGTTCATGAGTAA        #3CBC92         53
# pBICCNsMMrMOpRMiM006d190320_TTTGGTTTCGCAAGAG        #474662         90
# pBICCNsMMrMOpRMiM006d190320_TTTGTTGAGACTCTTG        #00CF1E         51
# pBICCNsMMrMOpRMiM006d190320_TTTGTTGTCACCTTGC        #3CBC92         52
# pBICCNsMMrMOpRMiM006d190320_TTTGTTGTCATGCTAG        #6F836B         48
#
#                                                cluster_label  gene.counts
# sample_name
# AAACCCAAGCTTCATG-1L8TX_181211_01_G12            L5 IT Tcap_2  7122.000000  \
# AAACCCAAGTGAGGTC-1L8TX_181211_01_G12            L5 IT Tcap_1  6125.000000
# AAACCCACACCAGCCA-1L8TX_181211_01_G12            L5 IT Tcap_2  8322.000000
# AAACCCAGTGAACGGT-1L8TX_181211_01_G12            L5 IT Tcap_1  8681.000000
# AAACCCAGTGGCATCC-1L8TX_181211_01_G12                Vip Gpc3  8081.000000
# ...                                                      ...          ...
# pBICCNsMMrMOpRMiM006d190320_TTTGGTTCATGAGTAA   L6 IT Sulf1_1  5218.066616
# pBICCNsMMrMOpRMiM006d190320_TTTGGTTTCGCAAGAG  Oligo Opalin_4  1740.348364
# pBICCNsMMrMOpRMiM006d190320_TTTGTTGAGACTCTTG     L5 IT S100b  5464.036043
# pBICCNsMMrMOpRMiM006d190320_TTTGTTGTCACCTTGC      L5 IT Pld5  5680.692074
# pBICCNsMMrMOpRMiM006d190320_TTTGTTGTCATGCTAG       L2/3 IT_1  5300.903467
#
#                                                  size subclass_label
# sample_name
# AAACCCAAGCTTCATG-1L8TX_181211_01_G12          17334.0          L5 IT  \
# AAACCCAAGTGAGGTC-1L8TX_181211_01_G12           7462.0          L5 IT
# AAACCCACACCAGCCA-1L8TX_181211_01_G12          17334.0          L5 IT
# AAACCCAGTGAACGGT-1L8TX_181211_01_G12           7462.0          L5 IT
# AAACCCAGTGGCATCC-1L8TX_181211_01_G12            314.0            Vip
# ...                                               ...            ...
# pBICCNsMMrMOpRMiM006d190320_TTTGGTTCATGAGTAA   3978.0          L6 IT
# pBICCNsMMrMOpRMiM006d190320_TTTGGTTTCGCAAGAG  16566.0          Oligo
# pBICCNsMMrMOpRMiM006d190320_TTTGTTGAGACTCTTG   8684.0          L5 IT
# pBICCNsMMrMOpRMiM006d190320_TTTGTTGTCACCTTGC   3621.0          L5 IT
# pBICCNsMMrMOpRMiM006d190320_TTTGTTGTCATGCTAG  23971.0        L2/3 IT
#
#                                                 umi.counts         dataset
# sample_name
# AAACCCAAGCTTCATG-1L8TX_181211_01_G12          55812.000000  scRNA_10x_v3 A
# AAACCCAAGTGAGGTC-1L8TX_181211_01_G12          36622.000000  scRNA_10x_v3 A
# AAACCCACACCAGCCA-1L8TX_181211_01_G12          90475.000000  scRNA_10x_v3 A
# AAACCCAGTGAACGGT-1L8TX_181211_01_G12          98226.000000  scRNA_10x_v3 A
# AAACCCAGTGGCATCC-1L8TX_181211_01_G12          74567.000000  scRNA_10x_v3 A
# ...                                                    ...             ...
# pBICCNsMMrMOpRMiM006d190320_TTTGGTTCATGAGTAA  18064.753140  snRNA_10x_v3 B
# pBICCNsMMrMOpRMiM006d190320_TTTGGTTTCGCAAGAG   3419.937704  snRNA_10x_v3 B
# pBICCNsMMrMOpRMiM006d190320_TTTGTTGAGACTCTTG  20579.022920  snRNA_10x_v3 B
# pBICCNsMMrMOpRMiM006d190320_TTTGTTGTCACCTTGC  22718.304610  snRNA_10x_v3 B
# pBICCNsMMrMOpRMiM006d190320_TTTGTTGTCATGCTAG  19543.896210  snRNA_10x_v3 B
#
# [258555 rows x 57 columns]

# %%
scvi.model.SCVI.setup_anndata(mdata, 
                              layer='counts', 
                              batch_key="sample_name", 
                              labels_key='subclass_label')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 scvi.model.SCVI.setup_anndata(mdata, layer=None, batch_key="sample_name", labels_key='subclass_label')
#
# File /opt/anaconda3/lib/python3.9/site-packages/scvi/model/_scvi.py:211, in SCVI.setup_anndata(cls, adata, layer, batch_key, labels_key, size_factor_key, categorical_covariate_keys, continuous_covariate_keys, **kwargs)
#     207     anndata_fields += cls._get_fields_for_adata_minification(adata_minify_type)
#     208 adata_manager = AnnDataManager(
#     209     fields=anndata_fields, setup_method_args=setup_method_args
#     210 )
# --> 211 adata_manager.register_fields(adata, **kwargs)
#     212 cls.register_manager(adata_manager)
#
# File /opt/anaconda3/lib/python3.9/site-packages/scvi/data/_manager.py:171, in AnnDataManager.register_fields(self, adata, source_registry, **transfer_kwargs)
#     166 if source_registry is None and transfer_kwargs:
#     167     raise TypeError(
#     168         f"register_fields() got unexpected keyword arguments {transfer_kwargs} passed without a source_registry."
#     169     )
# --> 171 self._validate_anndata_object(adata)
#     173 for field in self.fields:
#     174     self._add_field(
#     175         field=field,
#     176         adata=adata,
#     177         source_registry=source_registry,
#     178         **transfer_kwargs,
#     179     )
#
# File /opt/anaconda3/lib/python3.9/site-packages/scvi/data/_manager.py:111, in AnnDataManager._validate_anndata_object(self, adata)
#     105     _check_if_view(adata, copy_if_view=False)
#     107 if (
#     108     isinstance(adata, MuData)
#     109     and self.validation_checks.check_fully_paired_mudata
#     110 ):
# --> 111     _check_mudata_fully_paired(adata)
#
# File /opt/anaconda3/lib/python3.9/site-packages/scvi/data/_utils.py:247, in _check_mudata_fully_paired(mdata)
#     245 for mod_key in mdata.mod:
#     246     if not mdata.obsm[mod_key].all():
# --> 247         raise ValueError(
#     248             f"Detected unpaired observations in modality {mod_key}. "
#     249             "Please make sure that data is fully paired in all MuData inputs. "
#     250             "Either pad the unpaired modalities or take the intersection with muon.pp.intersect_obs()."
#     251         )
#
# ValueError: Detected unpaired observations in modality scrna. Please make sure that data is fully paired in all MuData inputs. Either pad the unpaired modalities or take the intersection with muon.pp.intersect_obs().
